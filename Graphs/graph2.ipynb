# %%
### multiple inputs

# %%
from typing import Dict, TypedDict, List
from langgraph import graph
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
    values: List[int]
    name: str
    result: str

# %%
def ProcessState(state: AgentState)->AgentState:
    """this function handles multiple different inputs"""
    print(state)
    state["result"] = f"Hi there {state["name"]}! Your sum = {sum(state["values"])}"
    print(state)
    return state

# %%
graph = StateGraph(AgentState)
graph.add_node("processor", ProcessState)
graph.set_entry_point("processor")
graph.set_finish_point("processor")

app = graph.compile()

# %%
answers = app.invoke({"values": [1,2,3,4], "name": "Arshad"})
# Out:
# {'values': [1, 2, 3, 4], 'name': 'Arshad'}
# {'values': [1, 2, 3, 4], 'name': 'Arshad', 'result': 'Hi there Arshad! Your sum = 10'}

# %%
print(answers["result"])
# Out:
# Hi there Arshad! Your sum = 10
